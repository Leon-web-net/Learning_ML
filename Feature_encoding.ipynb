# %% [markdown]
# <a href="https://colab.research.google.com/github/Leon-web-net/Learning_ML/blob/main/Feature_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import fetch_openml

data = fetch_openml(name="titanic", version=1, as_frame=True)
type(data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
data["target"]
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: survived, Length: 1309, dtype: category
# Categories (2, object): ['0', '1']

# %%
df_y = pd.DataFrame(data.target)
df_X = pd.DataFrame(data.data)

df_X.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0      0      0   24160  211.3375       B5        S    2    NaN
# 1      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# ...

# %%
df_y.head()
# Out:
#   survived
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

def LE_func(df, col):
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    return le

# %%
le_dict= {}

# %%
cols = ["sex", "embarked"]
for col in cols:
    if isinstance(df_X[col].dtype, pd.CategoricalDtype) or pd.api.types.is_object_dtype(df_X[col]):
      le_dict[col] = LE_func(df_X, col)
    else:
      print(f"{col} is of {df_X[col].dtype} and has not been labelEncoded")

df_X.head()
# Out:
#    pclass                                             name  sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton    0  29.0000
# 1       1                   Allison, Master. Hudson Trevor    1   0.9167
# 2       1                     Allison, Miss. Helen Loraine    0   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    1  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0  25.0000
#
#    sibsp  parch  ticket      fare    cabin  embarked boat   body  \
# 0      0      0   24160  211.3375       B5         2    2    NaN
# 1      1      2  113781  151.5500  C22 C26         2   11    NaN
# 2      1      2  113781  151.5500  C22 C26         2  NaN    NaN
# 3      1      2  113781  151.5500  C22 C26         2  NaN  135.0
# 4      1      2  113781  151.5500  C22 C26         2  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# ...

# %%
for col, le in le_dict.items():
    mapping = {label: idx for idx, label in enumerate(le.classes_)}
    print(f"{col}: {mapping}")
# Out:
# sex: {'female': 0, 'male': 1}
# embarked: {'C': 0, 'Q': 1, 'S': 2, nan: 3}

# %% [markdown]
# # Ordinal Encoding

# %%
from sklearn.datasets import fetch_openml

data = fetch_openml(name="credit-g", version=1, as_frame=True)
# Out:
#   checking_status  duration                  credit_history  \
# 0              <0         6  critical/other existing credit
# 1        0<=X<200        48                   existing paid
# 2     no checking        12  critical/other existing credit
# 3              <0        42                   existing paid
# 4              <0        24              delayed previously
#
#                purpose  credit_amount    savings_status employment  \
# 0             radio/tv           1169  no known savings        >=7
# 1             radio/tv           5951              <100     1<=X<4
# 2            education           2096              <100     4<=X<7
# 3  furniture/equipment           7882              <100     4<=X<7
# 4              new car           4870              <100     1<=X<4
#
#    installment_commitment     personal_status other_parties  residence_since  \
# 0                       4         male single          none                4
# ...

# %%
df_y = pd.DataFrame(data.target)
df_X = pd.DataFrame(data.data)

df_X.head()
# Out:
#   checking_status  duration                  credit_history  \
# 0              <0         6  critical/other existing credit
# 1        0<=X<200        48                   existing paid
# 2     no checking        12  critical/other existing credit
# 3              <0        42                   existing paid
# 4              <0        24              delayed previously
#
#                purpose  credit_amount    savings_status employment  \
# 0             radio/tv           1169  no known savings        >=7
# 1             radio/tv           5951              <100     1<=X<4
# 2            education           2096              <100     4<=X<7
# 3  furniture/equipment           7882              <100     4<=X<7
# 4              new car           4870              <100     1<=X<4
#
#    installment_commitment     personal_status other_parties  residence_since  \
# 0                       4         male single          none                4
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

def OE_func(df, col,cats):
    oe = OrdinalEncoder(categories=[cats])
    df[col] = oe.fit_transform(df[[col]]).astype(int)
    return oe

# %%
oe_dict = {}

# %%
cols = ["checking_status", "credit_history"]
[df_X[col].unique() for col in cols]
# Out:
# [['<0', '0<=X<200', 'no checking', '>=200']
#  Categories (4, object): ['0<=X<200', '<0', '>=200', 'no checking'],
#  ['critical/other existing credit', 'existing paid', 'delayed previously', 'no credits/all paid', 'all paid']
#  Categories (5, object): ['all paid', 'critical/other existing credit', 'delayed previously',
#                           'existing paid', 'no credits/all paid']]

# %%
category = {"checking_status": ['<0','no checking','0<=X<200','>=200'],
            "credit_history":['critical/other existing credit','delayed previously', 'existing paid', 'no credits/all paid', 'all paid']}
for col in cols:
    if isinstance(df_X[col].dtype, pd.CategoricalDtype) or pd.api.types.is_object_dtype(df_X[col]):
       oe_dict[col] = OE_func(df_X, col,category[col])
    else:
      print(f"{col} is of {df_X[col].dtype} and has not been labelEncoded")

df_X.head()
# Out:
#    checking_status  duration  credit_history              purpose  \
# 0                0         6               0             radio/tv
# 1                2        48               2             radio/tv
# 2                1        12               0            education
# 3                0        42               2  furniture/equipment
# 4                0        24               1              new car
#
#    credit_amount    savings_status employment  installment_commitment  \
# 0           1169  no known savings        >=7                       4
# 1           5951              <100     1<=X<4                       2
# 2           2096              <100     4<=X<7                       2
# 3           7882              <100     4<=X<7                       2
# 4           4870              <100     1<=X<4                       3
#
#       personal_status other_parties  residence_since property_magnitude  age  \
# ...

# %%
for col, oe in oe_dict.items():
    mapping = {label: idx for idx, label in enumerate(oe.categories_[0])}
    print(f"{col}: {mapping}")
# Out:
# checking_status: {'<0': 0, 'no checking': 1, '0<=X<200': 2, '>=200': 3}
# credit_history: {'critical/other existing credit': 0, 'delayed previously': 1, 'existing paid': 2, 'no credits/all paid': 3, 'all paid': 4}

# %% [markdown]
# # One hot encoding

# %%
import pandas as pd
from sklearn.datasets import fetch_openml

data = fetch_openml(name="titanic", version=1, as_frame=True)

# %%
df_y = pd.DataFrame(data.target)
df_X = pd.DataFrame(data.data)

df_X.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0      0      0   24160  211.3375       B5        S    2    NaN
# 1      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# ...

# %%
df_X = pd.get_dummies(df_X, columns=["sex", "embarked"], drop_first=True)
df_X.head()
# Out:
#    pclass                                             name      age  sibsp  \
# 0       1                    Allen, Miss. Elisabeth Walton  29.0000      0
# 1       1                   Allison, Master. Hudson Trevor   0.9167      1
# 2       1                     Allison, Miss. Helen Loraine   2.0000      1
# 3       1             Allison, Mr. Hudson Joshua Creighton  30.0000      1
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000      1
#
#    parch  ticket      fare    cabin boat   body  \
# 0      0   24160  211.3375       B5    2    NaN
# 1      2  113781  151.5500  C22 C26   11    NaN
# 2      2  113781  151.5500  C22 C26  NaN    NaN
# 3      2  113781  151.5500  C22 C26  NaN  135.0
# 4      2  113781  151.5500  C22 C26  NaN    NaN
#
#                          home.dest  sex_male  embarked_Q  embarked_S
# 0                     St Louis, MO     False       False        True
# 1  Montreal, PQ / Chesterville, ON      True       False        True
# ...

# %% [markdown]
# # Binary Encoder
